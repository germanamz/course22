# %% [markdown]
# # torch

# %%
import torch

# %%
X = torch.tensor([1,2,3,4], dtype=torch.float32)

# %%
Y = torch.tensor([2,4,6,8], dtype=torch.float32)

# %%
W = torch.tensor(0.0, dtype=torch.float32, requires_grad=True)

# %% [markdown]
# ### prediction

# %%
def forward(x):
    return W * x

# %% [markdown]
# ### loss

# %%
def loss(y, y_predicted):
    return ((y_predicted - y)**2).mean()

# %% [markdown]
# ### gradient
# dJ/dw = 1/N 2x (w*x - y)
#
# **Note:** Calculated by torch

# %%
def gradient(x, y, y_predicted):
    return np.dot(2*x, y_predicted - y).mean()

# %%
forward(5)
# Out:
# tensor(0., grad_fn=<MulBackward0>)

# %% [markdown]
# ### training

# %%
lr = 0.01

# %%
n_iters = 100

# %%
for epoc in range(n_iters):
    y_pred = forward(X)
    l = loss(Y, y_pred)
    
    # gradient = backward pass
    # dw = gradient(X, Y, y_pred)
    l.backward() # dl/dw
    
    # Update weights
    with torch.no_grad():
        W -= lr * W.grad
    
    W.grad.zero_()
    
    print(f"{epoc} W: {W}, loss: {l}")
# Out:
# 0 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 1 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 2 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 3 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 4 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 5 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 6 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 7 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 8 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 9 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 10 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 11 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 12 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 13 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 14 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 15 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 16 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 17 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 18 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 19 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 20 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 21 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 22 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 23 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 24 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 25 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 26 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 27 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 28 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 29 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 30 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 31 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 32 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 33 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 34 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 35 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 36 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 37 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 38 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 39 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 40 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 41 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 42 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 43 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 44 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 45 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 46 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 47 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 48 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 49 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 50 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 51 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 52 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 53 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 54 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 55 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 56 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 57 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 58 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 59 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 60 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 61 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 62 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 63 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 64 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 65 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 66 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 67 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 68 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 69 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 70 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 71 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 72 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 73 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 74 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 75 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 76 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 77 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 78 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 79 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 80 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 81 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 82 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 83 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 84 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 85 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 86 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 87 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 88 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 89 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 90 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 91 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 92 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 93 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 94 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 95 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 96 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 97 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 98 W: 1.9999996423721313, loss: 8.988365607365267e-13
# 99 W: 1.9999996423721313, loss: 8.988365607365267e-13
